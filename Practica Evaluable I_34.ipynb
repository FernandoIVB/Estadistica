# %% [markdown]
# # PRACTICA EVALUABLE I - Subgrupo 3.4

# %% [markdown]
# ### Ejercicio 1.
# En la base de datos **'PesoGas.csv'** tenemos los pesos (en la variable **Peso**) de una muestra de animales y la capacidad pulmonar en ml de cada uno de ellos (en la variable **Gas**).
#
# 1. **(0.25 pts.)** Importa los datos del fichero **'PesoGas.csv'** y muestra los primeros y los últimos datos del mismo. ¿Qué tipo de variables son **Peso** y **Gas**?
#
# 2. **(0.3 pts.)** Calcula el histograma de la variable **Gas**. Corta la variable **Gas** mediante los cortes dados por el histograma. Muestra la tabla estadística de dicha variable cortada. ¿qué conclusiones puedes deducir de **Gas**?
#
# 3. **(0.25 pts.)** Estudia los cuartiles y guarda los datos atípicos de la variable **Gas**. Compruéba los resultados mediante su diagrama caja-bigotes.
#
# 4. **(0.25 pts.)** Vamos a clasificar **Peso** en tres tipos: **Peso_pluma** (hasta 12 kg), **Peso_pesado** (más de 18 kg), y **Peso_medio** (el resto), así como **Gas** en dos tipos: **Gas_Asumible** (hasta 4000 ml) y **Gas_Tóxico** (más de 4000 ml). Para estas clasificaciones usa los nombres **Tipo_peso** y **Tipo_gas**.
#
# 5. **(0.35 pts.)** ¿Existe relación entre el peso de un animal y la cantidad de gas que pueden emitir? Haz uso de alguna tabla de contingencia para explicar si existe o no relación entre ambas variables.
#
# 6. **(0.35 pts.)** ¿Representa bien los datos la recta de regresión del gas respecto del peso de los animales? Lleva a cabo mediante el uso de logaritmos el modelo potencial
#
# $$G(p)=a\cdot p^b+c,$$
#
# donde p representa al **Peso**, G al **Gas**, y a, b, c son constantes a calcular.
#
# 7. **(0.25 pts.)** Predice la capacidad pulmonar de un animal de **30 kg**, por ambos modelos anteriores, tanto el normal como el potencial. Experimentalmente se obtuvo que el animal tenía una capacidad de **27850 ml**. *Cuál de los dos modelos se acerca más a la realidad? ¿Por qué?
